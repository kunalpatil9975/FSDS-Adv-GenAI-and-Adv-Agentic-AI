# %%
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
# Step 1: Create an imbalanced binary classification dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=2, n_redundant=8, 
                           weights=[0.9, 0.1], flip_y=0, random_state=42)

np.unique(y, return_counts=True)
# Out:
# (array([0, 1]), array([900, 100]))

# %%
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
# Define the model hyperparameters
params = {
    "solver": "lbfgs",
    "max_iter": 1000,
    "multi_class": "auto",
    "random_state": 42,
}

# Train the model
lr = LogisticRegression(**params)
lr.fit(X_train, y_train)

# Predict on the test set
y_pred = lr.predict(X_test)

report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       270
#            1       0.62      0.50      0.56        30
#
#     accuracy                           0.92       300
#    macro avg       0.79      0.73      0.76       300
# weighted avg       0.91      0.92      0.92       300

# %%
report_dict = classification_report(y_test, y_pred, output_dict=True)
report_dict
# Out:
# {'0': {'precision': 0.9456521739130435,
#   'recall': 0.9666666666666667,
#   'f1-score': 0.9560439560439561,
#   'support': 270.0},
#  '1': {'precision': 0.625,
#   'recall': 0.5,
#   'f1-score': 0.5555555555555556,
#   'support': 30.0},
#  'accuracy': 0.92,
#  'macro avg': {'precision': 0.7853260869565217,
#   'recall': 0.7333333333333334,
#   'f1-score': 0.7557997557997558,
#   'support': 300.0},
#  'weighted avg': {'precision': 0.9135869565217392,
#   'recall': 0.92,
#   'f1-score': 0.9159951159951161,
#   'support': 300.0}}

# %%
#!pip install mlflow
# Out:
# Collecting mlflow
#   Using cached mlflow-3.15.1-py3-none-any.whl.metadata (49 kB)
# Collecting mlflow-skinny==3.15.1 (from mlflow)
#   Using cached mlflow_skinny-3.15.1-py3-none-any.whl.metadata (50 kB)
# Collecting mlflow-tracing==3.15.1 (from mlflow)
#   Using cached mlflow_tracing-3.15.1-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow)
#   Using cached flask_cors-6.0.5-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: Flask<4 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow) (3.1.2)
# Requirement already satisfied: aiohttp<4,>=3.7.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow) (3.13.2)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Using cached alembic-1.19.1-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: cryptography<50,>=43.0.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow) (46.0.3)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Using cached docker-7.2.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting huey<4,>=2.5.4 (from mlflow)
#   Using cached huey-3.3.4-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: matplotlib<4 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow) (3.10.6)
# Requirement already satisfied: numpy<3 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow) (2.3.5)
# Requirement already satisfied: pandas<3 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow) (2.3.3)
# Requirement already satisfied: pyarrow<26,>=4.0.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow) (21.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow) (1.7.2)
# Requirement already satisfied: scipy<2 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow) (1.16.3)
# Collecting skops<1 (from mlflow)
#   Using cached skops-0.14.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow) (2.0.43)
# Collecting waitress<4 (from mlflow)
#   Using cached waitress-3.0.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: cachetools<8,>=5.0.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (8.2.1)
# Requirement already satisfied: cloudpickle<4 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.15.1->mlflow)
#   Using cached databricks_sdk-0.126.0-py3-none-any.whl.metadata (44 kB)
# Collecting fastapi<1 (from mlflow-skinny==3.15.1->mlflow)
#   Using cached fastapi-0.141.1-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<10,>=3.7.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (8.7.0)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==3.15.1->mlflow)
#   Using cached opentelemetry_api-1.44.0-py3-none-any.whl.metadata (1.4 kB)
# Collecting opentelemetry-proto<3,>=1.9.0 (from mlflow-skinny==3.15.1->mlflow)
#   Using cached opentelemetry_proto-1.44.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==3.15.1->mlflow)
#   Using cached opentelemetry_sdk-1.44.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: packaging<27 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (25.0)
# Requirement already satisfied: protobuf<8,>=3.12.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (5.29.3)
# Requirement already satisfied: pydantic<3,>=2.0.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (2.12.4)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (1.1.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (2.32.5)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==3.15.1->mlflow)
#   Using cached sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Collecting starlette<2 (from mlflow-skinny==3.15.1->mlflow)
#   Using cached starlette-1.6.0-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in c:\users\kunal\anaconda3\lib\site-packages (from mlflow-skinny==3.15.1->mlflow) (4.15.0)
# Collecting uvicorn<1 (from mlflow-skinny==3.15.1->mlflow)
#   Using cached uvicorn-0.52.1-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\kunal\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\kunal\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kunal\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\kunal\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\kunal\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\kunal\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\kunal\anaconda3\lib\site-packages (from aiohttp<4,>=3.7.0->mlflow) (1.22.0)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Using cached mako-1.4.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: colorama in c:\users\kunal\anaconda3\lib\site-packages (from click<9,>=7.0->mlflow-skinny==3.15.1->mlflow) (0.4.6)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\kunal\anaconda3\lib\site-packages (from cryptography<50,>=43.0.0->mlflow) (2.0.0)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow)
#   Downloading google_auth-2.56.3-py3-none-any.whl.metadata (6.0 kB)
# Collecting protobuf<8,>=3.12.0 (from mlflow-skinny==3.15.1->mlflow)
#   Downloading protobuf-6.33.6-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\kunal\anaconda3\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow) (2.5.0)
# Requirement already satisfied: pywin32>=304 in c:\users\kunal\anaconda3\lib\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\kunal\anaconda3\lib\site-packages (from fastapi<1->mlflow-skinny==3.15.1->mlflow) (0.4.2)
# Collecting annotated-doc>=0.0.2 (from fastapi<1->mlflow-skinny==3.15.1->mlflow)
#   Downloading annotated_doc-0.0.5-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\kunal\anaconda3\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\kunal\anaconda3\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\kunal\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\kunal\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in c:\users\kunal\anaconda3\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\kunal\anaconda3\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.15.1->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\kunal\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.15.1->mlflow) (4.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\kunal\anaconda3\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow) (0.4.2)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_core-3.2.11-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\kunal\anaconda3\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\kunal\anaconda3\lib\site-packages (from importlib_metadata!=4.7.0,<10,>=3.7.0->mlflow-skinny==3.15.1->mlflow) (3.23.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kunal\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\kunal\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kunal\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kunal\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\kunal\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kunal\anaconda3\lib\site-packages (from matplotlib<4->mlflow) (3.2.5)
# Collecting opentelemetry-semantic-conventions==0.65b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.15.1->mlflow)
#   Using cached opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kunal\anaconda3\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kunal\anaconda3\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\kunal\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.15.1->mlflow) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\kunal\anaconda3\lib\site-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.15.1->mlflow) (2.41.5)
# Requirement already satisfied: six>=1.5 in c:\users\kunal\anaconda3\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kunal\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.15.1->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kunal\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.15.1->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kunal\anaconda3\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==3.15.1->mlflow) (2025.11.12)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\kunal\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\kunal\anaconda3\lib\site-packages (from scikit-learn<2->mlflow) (3.5.0)
# Collecting prettytable>=3.9 (from skops<1->mlflow)
#   Using cached prettytable-3.18.0-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: greenlet>=1 in c:\users\kunal\anaconda3\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: anyio<5,>=3.6.2 in c:\users\kunal\anaconda3\lib\site-packages (from starlette<2->mlflow-skinny==3.15.1->mlflow) (4.10.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\kunal\anaconda3\lib\site-packages (from anyio<5,>=3.6.2->starlette<2->mlflow-skinny==3.15.1->mlflow) (1.3.0)
# Requirement already satisfied: h11>=0.8 in c:\users\kunal\anaconda3\lib\site-packages (from uvicorn<1->mlflow-skinny==3.15.1->mlflow) (0.16.0)
# Requirement already satisfied: pycparser in c:\users\kunal\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography<50,>=43.0.0->mlflow) (2.23)
# Collecting wcwidth>=0.3.5 (from prettytable>=3.9->skops<1->mlflow)
#   Downloading wcwidth-0.8.2-py3-none-any.whl.metadata (43 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\kunal\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.15.1->mlflow) (0.6.1)
# Using cached mlflow-3.15.1-py3-none-any.whl (11.2 MB)
# Using cached mlflow_skinny-3.15.1-py3-none-any.whl (3.6 MB)
# Using cached mlflow_tracing-3.15.1-py3-none-any.whl (1.8 MB)
# Using cached alembic-1.19.1-py3-none-any.whl (265 kB)
# Using cached databricks_sdk-0.126.0-py3-none-any.whl (1.1 MB)
# Using cached docker-7.2.0-py3-none-any.whl (148 kB)
# Using cached fastapi-0.141.1-py3-none-any.whl (131 kB)
# Using cached flask_cors-6.0.5-py3-none-any.whl (16 kB)
# Downloading google_auth-2.56.3-py3-none-any.whl (259 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached graphql_core-3.2.11-py3-none-any.whl (214 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached huey-3.3.4-py3-none-any.whl (123 kB)
# Using cached opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
# Using cached opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
# Using cached opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
# Using cached opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
# Downloading protobuf-6.33.6-cp310-abi3-win_amd64.whl (437 kB)
# Using cached skops-0.14.0-py3-none-any.whl (132 kB)
# Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Using cached starlette-1.6.0-py3-none-any.whl (75 kB)
# Using cached uvicorn-0.52.1-py3-none-any.whl (79 kB)
# Using cached waitress-3.0.2-py3-none-any.whl (56 kB)
# Downloading annotated_doc-0.0.5-py3-none-any.whl (5.3 kB)
# Using cached prettytable-3.18.0-py3-none-any.whl (37 kB)
# Downloading wcwidth-0.8.2-py3-none-any.whl (323 kB)
# Using cached mako-1.4.1-py3-none-any.whl (80 kB)
# Installing collected packages: huey, wcwidth, waitress, sqlparse, protobuf, opentelemetry-api, Mako, graphql-core, annotated-doc, uvicorn, starlette, prettytable, opentelemetry-semantic-conventions, opentelemetry-proto, graphql-relay, docker, alembic, skops, opentelemetry-sdk, graphene, google-auth, Flask-CORS, fastapi, databricks-sdk, mlflow-tracing, mlflow-skinny, mlflow
#
#    ----------------------------------------  0/27 [huey]
#   Attempting uninstall: wcwidth
#    ----------------------------------------  0/27 [huey]
#     Found existing installation: wcwidth 0.2.13
#    ----------------------------------------  0/27 [huey]
#     Uninstalling wcwidth-0.2.13:
#    ----------------------------------------  0/27 [huey]
#       Successfully uninstalled wcwidth-0.2.13
#    ----------------------------------------  0/27 [huey]
#    - --------------------------------------  1/27 [wcwidth]
#    - --------------------------------------  1/27 [wcwidth]
#    - --------------------------------------  1/27 [wcwidth]
#    -- -------------------------------------  2/27 [waitress]
#   Attempting uninstall: protobuf
#    -- -------------------------------------  2/27 [waitress]
#     Found existing installation: protobuf 5.29.3
#    -- -------------------------------------  2/27 [waitress]
#     Uninstalling protobuf-5.29.3:
#    -- -------------------------------------  2/27 [waitress]
#    ----- ----------------------------------  4/27 [protobuf]
#       Successfully uninstalled protobuf-5.29.3
#    ----- ----------------------------------  4/27 [protobuf]
#    ----- ----------------------------------  4/27 [protobuf]
#    ----- ----------------------------------  4/27 [protobuf]
#    ------- --------------------------------  5/27 [opentelemetry-api]
#    ---------- -----------------------------  7/27 [graphql-core]
#    ---------- -----------------------------  7/27 [graphql-core]
#    ---------- -----------------------------  7/27 [graphql-core]
#    ---------- -----------------------------  7/27 [graphql-core]
#    ------------- --------------------------  9/27 [uvicorn]
#    -------------- ------------------------- 10/27 [starlette]
#    -------------- ------------------ 12/27 [opentelemetry-semantic-conventions]
#    -------------- ------------------ 12/27 [opentelemetry-semantic-conventions]
#    -------------- ------------------ 12/27 [opentelemetry-semantic-conventions]
#    -------------------- ------------------- 14/27 [graphql-relay]
#    ---------------------- ----------------- 15/27 [docker]
#    ----------------------- ---------------- 16/27 [alembic]
#    ----------------------- ---------------- 16/27 [alembic]
#    ----------------------- ---------------- 16/27 [alembic]
#    ------------------------- -------------- 17/27 [skops]
#    -------------------------- ------------- 18/27 [opentelemetry-sdk]
#    -------------------------- ------------- 18/27 [opentelemetry-sdk]
#    ---------------------------- ----------- 19/27 [graphene]
#    ---------------------------- ----------- 19/27 [graphene]
#    ---------------------------- ----------- 19/27 [graphene]
#    ----------------------------- ---------- 20/27 [google-auth]
#    ----------------------------- ---------- 20/27 [google-auth]
#    -------------------------------- ------- 22/27 [fastapi]
#    ---------------------------------- ----- 23/27 [databricks-sdk]
#    ---------------------------------- ----- 23/27 [databricks-sdk]
#    ---------------------------------- ----- 23/27 [databricks-sdk]
#    ---------------------------------- ----- 23/27 [databricks-sdk]
#    ---------------------------------- ----- 23/27 [databricks-sdk]
#    ---------------------------------- ----- 23/27 [databricks-sdk]
#    ---------------------------------- ----- 23/27 [databricks-sdk]
#    ---------------------------------- ----- 23/27 [databricks-sdk]
#    ---------------------------------- ----- 23/27 [databricks-sdk]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ----------------------------------- ---- 24/27 [mlflow-tracing]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    ------------------------------------- -- 25/27 [mlflow-skinny]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    -------------------------------------- - 26/27 [mlflow]
#    ---------------------------------------- 27/27 [mlflow]
#
# Successfully installed Flask-CORS-6.0.5 Mako-1.4.1 alembic-1.19.1 annotated-doc-0.0.5 databricks-sdk-0.126.0 docker-7.2.0 fastapi-0.141.1 google-auth-2.56.3 graphene-3.4.3 graphql-core-3.2.11 graphql-relay-3.2.0 huey-3.3.4 mlflow-3.15.1 mlflow-skinny-3.15.1 mlflow-tracing-3.15.1 opentelemetry-api-1.44.0 opentelemetry-proto-1.44.0 opentelemetry-sdk-1.44.0 opentelemetry-semantic-conventions-0.65b0 prettytable-3.18.0 protobuf-6.33.6 skops-0.14.0 sqlparse-0.5.5 starlette-1.6.0 uvicorn-0.52.1 waitress-3.0.2 wcwidth-0.8.2

# %%
import mlflow

# %%
mlflow.set_experiment("1st Experiment")
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000/")
#mlflow.set_tracking_uri("http://localhost:5000")

with mlflow.start_run():
    mlflow.log_params(params)
    mlflow.log_metrics({
        'accuracy': report_dict['accuracy'],
        'recall_class_0': report_dict['0']['recall'],
        'recall_class_1': report_dict['1']['recall'],
        'f1_score_macro': report_dict['macro avg']['f1-score']
    })
    mlflow.sklearn.log_model(lr, "Logistic Regression")
# Out:
# 2026/08/12 08:58:53 WARNING mlflow.models.model: `artifact_path` is deprecated. Please use `name` instead.
# 🏃 View run gregarious-robin-279 at: http://127.0.0.1:5000/#/experiments/1/runs/31e3f52b5ed145f2917232e05fa1c4c0
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
